# %% [markdown]
# # Metody jądrowe (kernel methods)

# %% [markdown]
# ## Konfiguracja

# %% [markdown]
# Użyjemy bardzo standardowych narzędzi, tych samych, co na laboratorium 1.

# %%
# !pip install numpy scipy pandas matplotlib scikit-learn missingno

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ## Duży zbiór danych do klasyfikacji

# %% [markdown]
# Użyjemy najpierw bioinformatycznego zbioru danych [Cod-RNA](https://www.csie.ntu.edu.tw/~cjlin/libsvmtools/datasets/binary.html#cod-rna). Pochodzi on z artykułu ([link do wersji Open Access](https://bmcbioinformatics.biomedcentral.com/articles/10.1186/1471-2105-7-173)):
#
# > Uzilov, Andrew V., Joshua M. Keegan, and David H. Mathews. *"Detection of non-coding RNAs on the basis of predicted secondary structure formation free energy change."* BMC bioinformatics 7.1 (2006): 1-30. [link](https://bmcbioinformatics.biomedcentral.com/articles/10.1186/1471-2105-7-173)
#
# [Centralny dogmat biologii molekularnej (central dogma of molecular biology)](https://en.wikipedia.org/wiki/Central_dogma_of_molecular_biology) mówi, że przepływ informacji genetycznej przebiega z DNA przez RNA do białek. Innymi słowy, DNA zapisuje informację biologiczną, którą potem koduje RNA, z którego są syntezowane białka.
#
# W praktyce nie każde DNA i RNA koduje informacje. Kodujące DNA to zaledwie ok. 1-2% ludzkiego genomu, a reszta pełni różne role, głównie regulacyjne. W szczególności [niekodujące RNA (non-coding RNA, ncRNA)](https://en.wikipedia.org/wiki/Non-coding_RNA) pełni wiele różnych zadań, na przykład:
# - budują rybosomy odpowiadające za syntezę białek ([rRNA](https://en.wikipedia.org/wiki/Ribosomal_RNA))
# - transportują informację genetyczną ([tRNA](https://en.wikipedia.org/wiki/Transfer_RNA))
# - regulują ekspresję genów ([lncRNA](https://en.wikipedia.org/wiki/Long_non-coding_RNA))
#
# Nie są znane wszystkie funkcje niekodującego RNA, więc jest to aktywne pole badań. Najpierw trzeba jednak sprawdzić, czy dane RNA w ogóle jest kodujące, czy nie. Taka klasyfikacja jest nieoczywista, i też stanowi pole badań w bioinformatyce. Niektóre hipotezy wskazują, że struktura drugorzędowa RNA ma tutaj znacznie.
#
# Struktura pierwszorzędowa kwasu nukleinowego (DNA lub RNA) to po prostu liniowa sekwencja nukleotydów, np. ACCUUGCAUC. Struktura drugorzędowa oznacza ułożenie par nukleotydów (np. G-C, A-U) jednego lub dwóch łańcuchów.  Dla DNA to typowo podwójna helisa, natomiast RNA tworzy już bardzo bogate i złożone struktury. Przewidywanie struktury wyższego rzędu to typowe zadanie ML w bioinformatyce, bo sprawdzanie tego eksperymentalnie jest bardzo drogie.
#
# ![nucleic_acid_structures.png](nucleic_acid_structures.png)
#
# Przykładem algorytmu przewidującego strukturę drugorzędową jest [Dynalign](https://www.sciencedirect.com/science/article/abs/pii/S0022283601953513). Opiera się on na obserwacji, że niektóre struktury drugorzędowe RNA są bardziej stabilne od innych. Struktury o niższej energii są, zgodnie z zasadami termodynamiki, wolniejsze, a zatem stabilniejsze i bardziej prawdopodobne. Algorytm ten dodatkowo realizuje **dopasowanie sekwencji (sequence alignment)**, czyli takie "przyłożenie" do siebie sekwencji RNA, żeby jak najwięcej par pasowało do siebie. Wejściem do niego są 2 sekwencje RNA, a wyjściem ilość wolnej energii w optymalnej strukturze drugorzędowej RNA - im mniejsza, tym stabilniejsza jest struktura.
#
# Artykuł, z którego pochodzi nasz zbiór danych, zaproponował zastosowanie ML do klasyfikacji, czy dwie sekwencje RNA stanowią niekodujące RNA (ncRNA), czy też nie. Zbiór treningowy zbudowano z blisko 60 tysięcy par sekwencji RNA pochodzących z sekwencjonowania genomu bakterii *Escherichia coli* oraz *Salmonella enterica serovar Typhi (Salmonella typhi)*. Klasą pozytywną jest niekodujące RNA (5S rRNA albo tRNA), a negatywną losowo przemieszane nukleotydy z prawdziwej pary (istnieją do tego algorytmy tzw. sequence shuffling). Klasy są w stosunku 1:2, więc mamy klasyfikację lekko niezbalansowaną. Analogicznie stworzono zbiór testowy o wielkości nieco ponad 270 tysięcy par.
#
# Jako cech użyto:
# - wartości z algorytmu Dynalign
# - długości krótszej sekwencji
# - częstotliwości zasad azotowych A/U/C w sekwencji 1 (3 cechy)
# - częstotliwości zasad azotowych A/U/C w sekwencji 2 (3 cechy)
#
# Mamy zatem klasyfikację binarną, umiarkowanie niezbalansowaną, i 8 cech numerycznych. Jako metryk autorzy używają precyzji, czułości, krzywych ROC oraz wartości AUROC.
#
# My dla uproszczenia użyjemy F1-score, czyli średniej harmonicznej precyzji (precision) i czułości (recall). Obliczanie prawdopodobieństw w SVMach jest kosztowne i daje raczej niskiej jakości predykcje prawdopodobieństw, więc AUROC nie jest dla nich zbyt wygodną metryką.

# %% [markdown]
# Oryginalny zbiór jest w formacie `svmlight`, z którego korzystają biblioteki LibSVM i Liblinear. Są one standardowymi implementacjami SVMów. Sam ten format danych jest jednak tekstowy i zajmuje bardzo dużo miejsca, dlatego w tym repozytorium jest już przetworzony do formatu Parquet. Wczytamy teraz dane.
#
# Później trzeba dokonać normalizacji cech, tak jak zawsze w SVMach. Tak jak autorzy, wykonamy skalowanie min-max do zakresu [-1, 1].

# %% [markdown]
# **Zadanie 1 (0.5 punktu)**
#
# 1. Wczytaj dane treningowe z plików `cod_rna_train.parquet` oraz `cod_rna_test.parquet`.
# 2. Wyodrębnij kolumnę `y` do osobnych zmiennych `y_train` oraz `y_test`.
# 3. Dokonaj skalowania danych do zakresu [-1, 1], tworząc tablice `X_train_scaled` oraz `X_test_scaled`.

# %%
from sklearn.preprocessing import MinMaxScaler


cod_rna_train = pd.read_parquet("cod_rna_train.parquet")
cod_rna_test = pd.read_parquet("cod_rna_test.parquet")

y_train = cod_rna_train.pop("y")
y_test = cod_rna_test.pop("y")

X_train_scaled = MinMaxScaler(feature_range=(-1, 1)).fit_transform(
    cod_rna_train
)
X_test_scaled = MinMaxScaler(feature_range=(-1, 1)).fit_transform(cod_rna_test)

# %% [markdown]
# Skoro dane są gotowe, to wytrenujmy nasz pierwszy klasyfikator - liniowy SVM.
#
# W Scikit-learn funkcja kosztu (`loss`) to albo typowy hinge loss, albo squared hinge loss, czyli po prostu podniesiona do kwadratu. Wartość domyślna to `"squared_hinge"` - żeby dostać "typowego" SVMa, trzeba to zmienić. Jest różniczkowalna i mocniej kara duże błędy, ale jest też bardziej podatna na outliery. Dla zainteresowanych: [przystępny tutorial](https://github.com/christianversloot/machine-learning-articles/blob/main/how-to-use-hinge-squared-hinge-loss-with-keras.md) oraz artykuł naukowy:
#
# C.P. Lee, and C.J. Lin. *"A study on L2-loss (squared hinge-loss) multiclass SVM."* Neural computation 25.5 (2013): 1302-1323.
#
# Dodatkowo domyślna liczba iteracji solwera (1000) jest często dość niska, szczególnie przy dużych zbiorach. Zwiększymy to od razu, żeby mieć mniej warningów. Powyżej 10 tysięcy iteracji warningami można się już zazwyczaj nie przejmować.

# %%
from sklearn.metrics import f1_score
from sklearn.svm import LinearSVC


clf_linear_svc = LinearSVC(loss="hinge", max_iter=10000, random_state=0)
clf_linear_svc.fit(X_train_scaled, y_train)

y_pred = clf_linear_svc.predict(X_test_scaled)
print(f"F1-score: {100 * f1_score(y_test, y_pred):.2f}%")
# Out:
# F1-score: 93.00%

# %%
clf_linear_svc = LinearSVC(
    loss="hinge", max_iter=10000, random_state=0, class_weight="balanced"
)
clf_linear_svc.fit(X_train_scaled, y_train)

y_pred = clf_linear_svc.predict(X_test_scaled)
print(f"F1-score: {100 * f1_score(y_test, y_pred):.2f}%")
# Out:
# C:\Users\basia\anaconda3\lib\site-packages\sklearn\svm\_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# F1-score: 91.42%

# %% [markdown]
# ## Liniowy SVM

# %% [markdown]
# **Zadanie 2 (0.5 punktu)**
#
# Wytrenuj regresję logistyczną jako nasz **model baseline'owy**. Nasze bardziej złożone modele SVM muszą być od niego lepsze, żeby był w ogóle sens je rozważać.
#
# Użyj regularyzacji L2. Dokonaj tuningu siły regularyzacji (100 wartości) za pomocą 5-krotnej walidacji skrośnej. Jako metryki do tuningu użyj F1-score.
#
# Użyj zbalansowanych wag klas. W razie potrzeby zwiększ maksymalną liczbę iteracji solwera. Może się przydać `n_jobs`. Pamiętaj o ustawieniu `random_state=0`.
#
# Sprawdź wyniki algorytmu na zbiorze testowym.

# %% [markdown]
# ##### Logistic Regression without param tuning

# %%
from sklearn.linear_model import LogisticRegression


reg_logistic = LogisticRegression(
    class_weight="balanced", penalty="l2", random_state=0
)
reg_logistic.fit(X_train_scaled, y_train)

y_pred = reg_logistic.predict(X_test_scaled)
f1score = f1_score(y_test, y_pred)

print(f"F1-score: {f1score*100:.2f}%")
# Out:
# F1-score: 91.88%

# %% [markdown]
# ##### Cross-validated Logistic Regression with C tuning L2, <font color="green">tuning scoring="f1"</font>

# %%
from sklearn.linear_model import LogisticRegressionCV


reg_logistic_cv = LogisticRegressionCV(
    Cs=100,
    cv=5,
    class_weight="balanced",
    random_state=0,
    n_jobs=-1,
    scoring="f1",
    max_iter=10000,
)
reg_logistic_cv.fit(X_train_scaled, y_train)

y_pred_cv = reg_logistic_cv.predict(X_test_scaled)

f1_score_cv = reg_logistic_cv.score(X_test_scaled, y_test)
print(f"F1-score: {f1_score_cv * 100: .2f}%")
# Out:
# F1-score:  91.88%

# %% [markdown]
# ##### Cross-validated Logistic Regression with C tuning L2, <font color="green">tuning scoring="f1_weighted"</font>

# %%
reg_logistic_cv = LogisticRegressionCV(
    Cs=100,
    cv=5,
    class_weight="balanced",
    random_state=0,
    n_jobs=-1,
    scoring="f1_weighted",
    max_iter=10000,
)
reg_logistic_cv.fit(X_train_scaled, y_train)

y_pred_cv = reg_logistic_cv.predict(X_test_scaled)

f1_score_cv = reg_logistic_cv.score(X_test_scaled, y_test)
print(f"F1-score: {f1_score_cv * 100: .2f}%")
# Out:
# F1-score:  94.34%

# %% [markdown]
# Nasz SVM bez żadnego tuningu jest zasadniczo tak dobry, jak regresja logistyczna z tuningiem - całkiem nieźle. No ale czas teraz na tuning samego SVMa.
#
# Najpierw warto wiedzieć jeszcze parę rzeczy o implementacji użytej w Scikit-learn, korzystającej pod spodem z Liblinear.
#
# Argument `dual` wyznacza, czy skorzystać z postaci primal, czy dual. Jeżeli liczba próbek jest znacznie większa od liczby cech, albo ogółem mamy sporo próbek, to lepiej użyć primal `dual=False`. Niestety, wtedy mamy do dyspozycji tylko funkcję kosztu `squared_hinge`.
#
# SVM jest stricte jednowątkowy (sekwencyjny), więc równoległość można wykorzystać przy tuningu hiperparametrów. Zdecydowanie warto użyć tu `n_jobs=-1`.
#
# **Uwaga:** jako że osobne joby są tworzone jako osobne procesy, to wyłączenie `ConvergenceWarning` jest nietrywialne, a czasem niemożliwe. Sugeruję to po prostu zignorować.
#
# **Zadanie 3 (1 punkt)**
#
# Dokonaj tuningu hiperparametru `C` liniowego SVM. Użyj 5-krotnej walidacji skrośnej, wybierając model o najwyższym F1-score. Użyj zbalansowanych wag klas i funkcji kosztu hinge loss. Pamiętaj o stałym `random_state`.
#
# Zastosuj iteracyjne zagęszczanie siatki. Najpierw sprawdź wartości z zakresu `[1e-3, 1e-2, 1e-1, 1, 1e1, 1e2]` i znajdź optymalną wartość `C`. Następnie wedle własnego uznania zagęść siatkę wokół znalezionego optymalnego C. Może się przydać `np.linspace()` albo `list(range())`. Jeżeli w takiej operacji wychodzi optymalne `C` na granicy (najmniejsze albo największe możliwe), to warto sprawdzić większe wartości niż dotychczas rozważane. Powtórz takie działanie 2-3 razy. W praktyce jednak `C` większe niż kilkaset nie ma sensu w kontekście SVMów.
#
# Wypisz ostatecznę znalezioną optymalną wartość odwrotności siły optymalizacji `C`. Sprawdź wynik na zbiorze testowym. Czy udało się przebić baseline?

# %%
import warnings


# To ignore some annoying warnings
warnings.simplefilter(action="ignore", category=(FutureWarning, UserWarning))

# %%
from sklearn.model_selection import GridSearchCV


data = X_train_scaled, y_train, X_test_scaled, y_test


def grid_search(data, clf, C_vals, scoring="f1"):
    X_train_scaled, y_train, X_test_scaled, y_test = data

    param_grid = {
        "C": C_vals,
    }

    cv = GridSearchCV(
        estimator=clf, param_grid=param_grid, scoring=scoring, cv=5, n_jobs=-1
    )

    cv.fit(X_train_scaled, y_train)
    y_pred = cv.predict(X_test_scaled)
    print(f"F1-score: {100 * f1_score(y_test, y_pred):.2f}%")
    print(f"Optimal C value: {cv.best_params_}")

    return cv, y_pred

# %%
clf_linear_svc = LinearSVC(
    dual=False,
    loss="squared_hinge",
    class_weight="balanced",
    max_iter=10000,
    random_state=0,
)
clf_linear_svc.fit(X_train_scaled, y_train);

# %%
# 0.001, 0.01, 0.1, 1, 10, 100
C_vals = list([1e-3, 1e-2, 1e-1, 1, 1e1, 1e2])
cv, y_pred = grid_search(data, clf_linear_svc, C_vals);
# Out:
# F1-score: 91.47%
# Optimal C value: {'C': 0.01}

# %%
C_vals = np.linspace(0.001, 1, 100)
grid_search(data, clf_linear_svc, C_vals);
# Out:
# F1-score: 91.48%
# Optimal C value: {'C': 0.011090909090909092}

# %%
C_vals = np.linspace(0.5, 1.5, 100)
grid_search(data, clf_linear_svc, C_vals);
# Out:
# F1-score: 91.77%
# Optimal C value: {'C': 0.6212121212121212}

# %%
C_vals = np.linspace(0.5, 500, 1000)
cv, y_pred = grid_search(data, clf_linear_svc, C_vals);
# Out:
# F1-score: 91.78%
# Optimal C value: {'C': 167.0}

# %%
C_vals = np.linspace(0.001, 200, 1000)
grid_search(data, clf_linear_svc, C_vals);
# Out:
# F1-score: 91.78%
# Optimal C value: {'C': 167.16733133133135}

# %%
C_vals = np.linspace(100, 300, 100)
grid_search(data, clf_linear_svc, C_vals);
# Out:
# F1-score: 91.78%
# Optimal C value: {'C': 168.6868686868687}

# %%
C_vals = np.linspace(100, 200, 1000)
grid_search(data, clf_linear_svc, C_vals);
# Out:
# F1-score: 91.78%
# Optimal C value: {'C': 167.06706706706706}

# %% [markdown]
# // skomentuj tutaj
#
# Na podstawie grid searcha optymalne C to ok. 167, +/- 1. Co ciekawe, drugim w kolejności najlepszym C jest 0.011. Jak widać wartości optymalne funkcji mogą być porozrzucane po różnych przedziałach wartości C.
#
# Nie udało się przebić modelu regresji liniowej, w której F1-score = 91.88%. Jesteśmy 0.10% niżej. Nie udało się też przebić modelu liniowego SVM z C=1. Powodem jest użycie class_weight = "balanced", czego nie zrobiliśmy w przykładzie w zad. 1.

# %% [markdown]
# Może się to jeszcze uda poprawić - w końcu w artykule autorzy używali kernel SVM, a nie liniowego!

# %% [markdown]
# ## Kernel SVM

# %% [markdown]
# Kernel SVM w Scikit-learn jest implementowany w klasie `SVC`. Wypróbujmy podstawową wersję, bez tuningu hiperparametrów. Przy okazji wiemy, że złożoność kernel SVM to co najmniej $O(n^2)$ - zobaczmy, ile to zajmuje w praktyce.
#
# Warto zawsze ustawić nieco wyższą wartość `cache_size` niż domyślna. Jest to ilość MB na cache'owanie obliczonych wartości kerneli. Warto jednak uważać na zbyt duże wartości:
# - wartości ponad 2000 mogą [powodować problemy przez buga w LibSVM](https://github.com/scikit-learn/scikit-learn/issues/8012)
# - sama alokacja dużej ilości pamięci (ciągłej!) może zajmować dużo czasu
# - nie wszystkie wartości kerneli będą używane często, więc nie wszystkie jest sens cache'ować

# %%
from time import time
from sklearn.svm import SVC


clf_kernel_svc = SVC(cache_size=512, class_weight="balanced", random_state=0)
start_time = time()
clf_kernel_svc.fit(X_train_scaled, y_train)
end_time = time()
training_time = end_time - start_time

y_pred = clf_kernel_svc.predict(X_test_scaled)

print(f"F1-score: {100 * f1_score(y_test, y_pred):.2f}%")
print(f"Training time: {training_time} s")
# Out:
# F1-score: 93.38%
# Training time: 144.29520535469055 s

# %% [markdown]
# Wynik jest ewidentnie lepszy, bez żadnego tuningu! Zajmuje to jednak sporo czasu. Ale nasz zbiór treningowy to ok. 60 tysięcy, a testowy 270 tysięcy - może to predykcja tyle zajmuje, a nie sam trening?
#
# **Zadanie 4 (1 punkt)**
#
# 1. Sprawdź liczbę support vectors dla liniowego i kernel SVM. Sprawdź, jaki procent wszystkich punktów one stanowią. Czy rzadkość (sparsity) została osiągnięta? Może się przydać [ten przykład](https://scikit-learn.org/stable/auto_examples/svm/plot_linearsvc_support_vectors.html), żeby zliczyć support vectors dla liniowego SVM (`X` to u nas `X_train_scaled`).
# 2. Porównaj czas predykcji na zbiorze testowym dla regresji logistycznej, liniowego SVM i kernel SVM. Uwzględniając rozmiar zbioru testowego, czy twoim zdaniem to dużo?

# %% [markdown]
# #### Times benchmark

# %% [markdown]
# ##### <font color="navy">Linear Regression</font>

# %%
C_opt = reg_logistic_cv.C_[0]

reg_logistic = LogisticRegression(
    C=C_opt, class_weight="balanced", penalty="l2", random_state=0
)
start_time = time()
reg_logistic.fit(X_train_scaled, y_train)
end_time = time()
fit_time = end_time - start_time

start_time = time()
y_pred = reg_logistic.predict(X_test_scaled)
end_time = time()
pred_time = end_time - start_time

print(f"F1-score: {f1_score(y_test, y_pred)*100:.2f}%")
print(f"Training time: {fit_time:.2f} s")
print(f"Prediction time: {pred_time:.2f} s")
# Out:
# F1-score: 91.88%
# Training time: 0.36 s
# Prediction time: 0.02 s

# %% [markdown]
# ##### <font color="navy">LinearSVM</font>

# %%
C_opt = cv.best_params_["C"]

clf_linear_svc = LinearSVC(
    C=C_opt,
    dual=False,
    loss="squared_hinge",
    class_weight="balanced",
    max_iter=10000,
    random_state=0,
)
start_time = time()
clf_linear_svc.fit(X_train_scaled, y_train)
end_time = time()
fit_time = end_time - start_time

start_time = time()
y_pred = clf_linear_svc.predict(X_test_scaled)
end_time = time()
pred_time = end_time - start_time

print(f"F1-score: {100 * f1_score(y_test, y_pred):.2f}%")
print(f"Training time: {fit_time:.2f} s")
print(f"Prediction time: {pred_time:.2f} s")
# Out:
# F1-score: 91.78%
# Training time: 0.27 s
# Prediction time: 0.02 s

# %% [markdown]
# ##### <font color="navy">KernelSVM</font>

# %%
clf_kernel_svc = SVC(cache_size=512, class_weight="balanced", random_state=0)

start_time = time()
clf_kernel_svc.fit(X_train_scaled, y_train)
end_time = time()
fit_time = end_time - start_time

start_time = time()
y_pred = clf_kernel_svc.predict(X_test_scaled)
end_time = time()
pred_time = end_time - start_time

print(f"F1-score: {100 * f1_score(y_test, y_pred):.2f}%")
print(f"Training time: {fit_time:.2f} s")
print(f"Prediction time: {pred_time:.2f} s")
# Out:
# F1-score: 93.38%
# Training time: 124.27 s
# Prediction time: 781.47 s

# %% [markdown]
# // Czas- wnioski
#
# Zbiór testowy jest duży, 260 tyś. próbek. Regresja logistyczna, zgodnie z oczekiwaniami, których nabyliśmy na poprzednich laboratoriach, policzyła wszystko bardzo szybko. Liniowy SVC podobnie do regresji, z minimalnie niższym F1-score (-0.1% względem regresji log.). Kernel SVM fittował bardzo długo, a predykował 13 min - to, moim zdaniem, bardzo długo, ale zrozumiałe względem tak dużej l. próbek.

# %% [markdown]
# #### Support Vectors

# %%
from termcolor import colored


def get_support_vectors(clf_svc, X_train_scaled, margin_treshold=(1 + 1e-15)):
    # we can also calculate the decision function manually
    # decision_function = np.dot(X, clf.coef_[0]) + clf.intercept_[0]
    decision_function = clf_svc.decision_function(X_train_scaled)

    # The support vectors are the samples that lie within the margin
    # boundaries, whose size is conventionally constrained to 1
    support_vector_indices = np.where(
        np.abs(decision_function) <= margin_treshold
    )[0]
    support_vectors = X_train_scaled[support_vector_indices]

    print(f"All vector samples no: {X_train_scaled.shape[0]}")
    print(f"Support vectors no: {support_vectors.shape[0]}")
    print(
        colored(
            f"Support vectors %: \
            {support_vectors.shape[0] / X_train_scaled.shape[0] * 100:.2f}",
            "blue",
        )
    )

    return support_vectors, support_vector_indices


def support_vector_analysis(y_train, support_vectors, support_vector_indices):
    negative_class_no = y_train[support_vector_indices].value_counts()[-1]
    positive_class_no = y_train[support_vector_indices].value_counts()[1]

    print(
        colored(
            f"Positive class %: \
            {positive_class_no / (support_vectors.shape[0]) * 100:.2f}",
            "blue",
        )
    )

# %% [markdown]
# ##### <font color="navy">Training set</font>

# %%
negative_class_no = y_train.value_counts()[-1]
positive_class_no = y_train.value_counts()[1]
class_ratio = positive_class_no / (positive_class_no + negative_class_no) * 100

print(colored(f"Positive class %: {class_ratio:.2f}", "blue"))
# Out:
# Positive class %: 33.33

# %% [markdown]
# ##### <font color="navy">LinearSVM</font>

# %%
supp_vecs_lin, supp_vecs_lin_indices = get_support_vectors(
    clf_linear_svc, X_train_scaled
)
# Out:
# All vector samples no: 59535
# Support vectors no: 23969
# Support vectors %: 40.26

# %%
support_vector_analysis(y_train, supp_vecs_lin, supp_vecs_lin_indices)
# Out:
# Positive class %: 39.24

# %% [markdown]
# ##### <font color="navy">KernelSVM</font>

# %% [markdown]
# - Custom, "homemade" support vectors analysis

# %%
supp_vecs_kernel, supp_vecs_kernel_indices = get_support_vectors(
    clf_kernel_svc, X_train_scaled
)
# Out:
# All vector samples no: 59535
# Support vectors no: 8449
# Support vectors %: 14.19

# %%
support_vector_analysis(y_train, supp_vecs_kernel, supp_vecs_kernel_indices)
# Out:
# Positive class %: 37.06

# %% [markdown]
# - SVC attributes support vectors analysis

# %%
supp_vecs_SVC_indices = clf_kernel_svc.support_
negative_class_no_SVC, positive_class_no_SVC = clf_kernel_svc.n_support_
vectors_ratio = (
    clf_kernel_svc.support_vectors_.shape[0] / X_train_scaled.shape[0] * 100
)
class_ratio = (
    positive_class_no_SVC / clf_kernel_svc.support_vectors_.shape[0] * 100
)

print(
    f"Support vectors no: \
{clf_kernel_svc.support_vectors_.shape[0]}"
)
print(f"Support vectors %: {vectors_ratio:.2f}")
print(f"Positive class %: {class_ratio:.2f}")
# Out:
# Support vectors no: 9524
# Support vectors %: 16.00
# Positive class %: 33.50

# %% [markdown]
# Jak widać, threshold wartości szerokości marginesu = 1 + 1e-15 okazał się być trochę zbyt rygorystyczny - wyznaczono w ten "ręczny" sposób mniej wektorów nośnych (8449) niż wyznaczył ich SVC w swoich atrybutach (9524). Być może powodem jest inne robocze (implementacyjne) epsilon niż 1e-15 (większe) - na pewno dałoby się poznać przyczynę z kodu źródłowego biblioteki. Na poniższym wykresie dla Kernel SV uwzględniam własnoręcznie wyznaczone custom support vectors, dla porównania z Linear SV.

# %% [markdown]
# ##### <font color="navy">Summary</font>

# %%
ax = y_train.value_counts().plot.bar(title="Target values distribution")
y_train[supp_vecs_lin_indices].value_counts().plot.bar(color="purple")
y_train[supp_vecs_kernel_indices].value_counts().plot.bar(
    color="orange", rot=0
)
ax.legend(
    [
        "Training set target values",
        "Linear SV target values",
        "Kernel SV target values",
    ]
);

# %% [markdown]
# // skomentuj tutaj
#
# Linear SVM ustanowił granicę decyzyjną na podstawie 40% liczności próbek dataseta, kernel SVM na podstawie 14-16%. W drugim przypadku można mówić o swego rodzaju sparsity. Jednak czas predykcji dla Kernel SVC jest bardzo długi.

# %% [markdown]
# Taki zbiór jest już dość ekstremalny dla kernel SVM. Tego algorytmu w praktyce nie stosuje się wprost dla zbiorów wielkości dziesiątek tysięcy próbek treningowych, bo byłoby to zbyt wolne. Można tu natomiast zastosować podobną sztuczkę, co z kNN i ANN, czyli aproksymować - w tym wypadku macierz kerneli. Dotyczy tego zadanie dodatkowe.
#
# Dodatkowo implementacja ze Scikit-learn potrafi być zaskakująco wolna. W praktyce LibSVM, użyty jako [samodzielna biblioteka](https://pypi.org/project/libsvm-official/), potrafi być o wiele szybszy. Ma za to dużo brzydszy interfejs.
#
# W praktyce kernel SVM jest używany najczęściej, kiedy mamy mało danych i trzeba bardzo dokładnego klasyfikatora, a jego duży koszt nie jest tak odczuwalny.

# %% [markdown]
# ## Mały zbiór danych do klasyfikacji

# %% [markdown]
# Jako drugi zbiór wykorzystamy [Iranian Churn Dataset](https://archive.ics.uci.edu/ml/datasets/Iranian+Churn+Dataset) ([Kaggle](https://www.kaggle.com/datasets/royjafari/customer-churn)). Dotyczy on klasyfikacji, czy dany klient telekomunikacyjny zmieni dostawcę, czyli nastąpi tzw. odpływ klienta (*customer churn*). Jest to bardzo ważne i częste zadanie w telekomunikacji i usługach, szczególnie w biznesach, gdzie pozyskanie całkiem nowych klientów jest bardzo trudne albo praktycznie niemożliwe, a trzeba ich w praktyce odebrać konkurencji. To właśnie sytuacja firm telekomunikacyjnych - telefon czy internet ma praktycznie każdy, więc zdobywanie nowych klientów jest drogie. Dużo bardziej opłaca się identyfikować "ryzykownych" klientów i ich zachęcić do pozostania, np. promocjami.
#
# Dane zostały pozyskane z irańskich firm telekomunikacyjnych (konkretnie z call center obsługującego takie firmy). [Historia telekomunikacji w Iranie](https://en.wikipedia.org/wiki/Communications_in_Iran) jest ciekawa sama w sobie i pokazuje, czemu w tym kraju to było szczególnie ważne. Iran w 2008 roku miał populację ponad 80 milionów ludzi, z czego około 56% poniżej 25 roku życia - idealny i duży rynek dla nowych technologii. Ponadto samo zainteresowanie było ogromne, a tempo rozwoju kraju oraz prywatyzacja państwowych spółek stworzyły niesamowicie konkurencyjny rynek. Churn prediction stało się bardzo ważnym finansowo zadaniem dla wielu spółek.
#
# Z perspektywy ML, churn prediction to praktycznie zawsze klasyfikacja binarna i niezbalanansowana - zwykle mało który klient odchodzi.
#
# Zbiór ten został zebrany przez autorów na potrzeby artykułu:
#
# > Keramati, Abbas, and Seyed MS Ardabili. *"Churn analysis for an Iranian mobile operator."* Telecommunications Policy 35.4 (2011): 344-356.
#
# Churn prediction z użyciem tego zbioru zostało przez nich zastosowane w artykułach:
#
# > Keramati, Abbas, et al. *"Improved churn prediction in telecommunication industry using data mining techniques."* Applied Soft Computing 24 (2014): 994-1012.
#
# > Jafari-Marandi, Ruholla, et al. *"Optimum profit-driven churn decision making: innovative artificial neural networks in telecom industry."* Neural Computing and Applications 32 (2020): 14929-14962.
#
# Dane są wysokiej jakości - ludzi monitorowano przez 12 miesięcy, aby uzyskać miarodajną informację w czasie, czy odejdą do innego operatora. Dodatkowo nie mają wartości brakujących i outlierów, a wszystkie zmienne są numeryczne. Zastosowaną w artykułach metryką jest F1-score.
#
# Zbiór został wzięty z Kaggle (opublikował go tam Ruholla Jafari-Marandi). W dodatku do zmiennych opisanych na stronie UCI, zawiera on oszacowaną wartość FP i FN dla każdego klienta. Wykorzystamy to później - w końcu utrata dużo płacącego klienta jest bardziej kosztowna.

# %% [markdown]
# **Zadanie 5 (1 punkt)**
#
# 1. Wczytaj dane z pliku `customer_churn_data.csv`.
# 2. Wyodrębnij kolumny do zmiennych:
#    - `Churn` do zmiennej `y`
#    - `FN` do zmiennej `fn_cost`
#    - `FP` do zmiennej `fp_cost`
# 3. Narysuj wykres słupkowy (bar plot) częstości klas. Pamiętaj o opisaniu wykresu.
# 4. Podziel zbiór na treningowy i testowy w proporcjach 75%-25% ze stratyfikacją. Pamiętaj o stałym `random_state=0`. Uwaga - podziel też `fn_cost` oraz `fp_cost` na treningowe i testowe.
# 5. Dokonaj standaryzacji zmiennych.

# %%
df = pd.read_csv("customer_churn_data.csv")

y = df.pop("Churn")
fn_cost = df.pop("FN")
fp_cost = df.pop("FP")

# %%
fig, axes = plt.subplots(1, 2, figsize=(10, 4))

class_frequencies = y.value_counts() / y.value_counts().sum() * 100
class_frequencies = class_frequencies.sort_index()

class_frequencies.plot.bar(ax=axes[0], rot=0, grid=True)
y.value_counts().plot.bar(ax=axes[1], rot=0, grid=True)

axes[0].set_title("Class frequencies in %")
axes[0].set_xlabel("churn values")
axes[0].set_ylabel("Sample %")

for container in axes[0].containers:
    axes[0].bar_label(container, fmt="%.2f%%")

axes[1].set_title("Class absolute frequencies")
axes[1].set_xlabel("churn values")
axes[1].set_ylabel("Samples")

for container in axes[1].containers:
    axes[1].bar_label(container)

plt.show()

# %%
from sklearn.model_selection import train_test_split


(
    X_train,
    X_test,
    y_train,
    y_test,
    fn_cost_train,
    fn_cost_test,
    fp_cost_train,
    fp_cost_test,
) = train_test_split(
    df, y, fn_cost, fp_cost, test_size=0.25, random_state=0, stratify=y
)

# %%
from sklearn.preprocessing import StandardScaler


standard_scaler = StandardScaler()

X_train = pd.DataFrame(
    standard_scaler.fit_transform(X_train), columns=list(df.columns)
)
X_test = pd.DataFrame(
    standard_scaler.transform(X_test), columns=list(df.columns)
)

# %%
# to_pd_series = lambda data, indexes: pd.Series(data, index=indexes)

# idxs = fn_cost_train.index.copy()
# fn_cost_train = to_pd_series(
#     standard_scaler.fit_transform(
#         np.array(fn_cost_train).reshape(-1, 1)
#     ).flatten(),
#     idxs,
# )

# idxs = fn_cost_test.index.copy()
# fn_cost_test = to_pd_series(
# standard_scaler
# .transform(np.array(fn_cost_test).reshape(-1, 1)).flatten(),
#     idxs,
# )

# idxs = fp_cost_train.index.copy()
# fp_cost_train = to_pd_series(
#     standard_scaler.fit_transform(
#         np.array(fp_cost_train).reshape(-1, 1)
#     ).flatten(),
#     idxs,
# )

# idxs = fp_cost_test.index.copy()
# fp_cost_test = to_pd_series(
# standard_scaler
# .transform(np.array(fp_cost_test).reshape(-1, 1)).flatten(),
#     idxs,
# )

# %% [markdown]
# **Zadanie 6 (1.5 punktu)**
#
# 1. Wytrenuj regresję logistyczną jako baseline, dokonując tuningu analogicznie do zadania 2. Pamiętaj o ustawieniu `random_state=0`. Zmierz czas treningu (włącznie z tuningiem). Sprawdź F1-score na zbiorze testowym
# 2. Wytrenuj liniowy SVM:
#    - ustaw maksymalnie 10000 iteracji i zbalansowane wagi klas
#    - dokonaj tuningu hiperparametru `C` za pomocą 5-krotnej walidacji skrośnej
#    - sprawdź 100 wartości z zakresu od $10^{-2}$ do $10^2$
#    - wypisz znalezioną optymalną wartość `C`
#    - wybierz model o najwyższym F1-score
#    - zmierz czas treningu (włącznie z tuningiem)
#    - sprawdź F1-score na zbiorze testowym
#    - pamiętaj o ustawieniu `random_state=0`

# %% [markdown]
# #### Logistic Regression

# %%
from sklearn.linear_model import LogisticRegressionCV
from sklearn.metrics import f1_score
from time import time


reg_logistic_cv = LogisticRegressionCV(
    Cs=100,
    cv=5,
    class_weight="balanced",
    random_state=0,
    n_jobs=-1,
    scoring="f1",
    max_iter=10000,
)

start_time = time()
reg_logistic_cv.fit(X_train, y_train)
end_time = time()
fit_time = end_time - start_time

start_time = time()
y_pred = reg_logistic_cv.predict(X_test)
end_time = time()
pred_time = end_time - start_time

print(f"F1-score: {f1_score(y_test, y_pred)*100:.2f}%")
print(f"Training time: {fit_time:.2f} s")
print(f"Prediction time: {pred_time:.2f} s")
# Out:
# F1-score: 61.05%
# Training time: 0.49 s
# Prediction time: 0.00 s

# %%
C_best = reg_logistic_cv.C_
C_best
# Out:
# array([2.7825594])

# %% [markdown]
# #### LinearSVM

# %%
data = X_train, y_train, X_test, y_test


def grid_search(data, clf, C_vals, scoring="f1"):
    X_train_scaled, y_train, X_test_scaled, y_test = data

    param_grid = {
        "C": C_vals,
    }

    cv = GridSearchCV(
        estimator=clf,
        param_grid=param_grid,
        scoring=scoring,
        cv=5,
        n_jobs=-1,
        return_train_score=True,
    )

    # Start of tuning in here
    # - run fit with all sets of parameters
    start_time = time()
    cv.fit(X_train_scaled, y_train)
    end_time = time()
    fit_time = end_time - start_time
    # End of tuning in here

    # Call predict on the estimator
    # with the best found parameters
    start_time = time()
    y_pred = cv.predict(X_test_scaled)
    end_time = time()
    fit_time = end_time - start_time

    print(f"Fit time: {fit_time:.2f} s")
    print(f"Prediction time: {pred_time:.2f} s")
    print(f"F1-score: {100 * f1_score(y_test, y_pred):.2f}%")
    print(f"Optimal C value: {cv.best_params_}")

    return cv, y_pred

# %%
clf_linear_svc = LinearSVC(
    dual=False,
    loss="squared_hinge",
    class_weight="balanced",
    max_iter=10000,
    random_state=0,
)
clf_linear_svc.fit(X_train, y_train)

results = {}

# %%
C_vals = np.linspace(0.01, 100, 100)
results[1] = grid_search(data, clf_linear_svc, C_vals);
# Out:
# Fit time: 0.00 s
# Prediction time: 0.00 s
# F1-score: 61.95%
# Optimal C value: {'C': 22.23}

# %%
cv, y_pred = results[1]

# %%
# As a proof that something actually happened
# in this 0.00 s timeline :)
cv.cv_results_
# Out:
# {'mean_fit_time': array([0.01060004, 0.01359997, 0.01099958, 0.01240025, 0.01319995,
#         0.01079979, 0.01280041, 0.0132    , 0.01080003, 0.01140018,
#         0.01059976, 0.01059976, 0.01100039, 0.01159835, 0.0109993 ,
#         0.01040025, 0.01080041, 0.01079865, 0.01039867, 0.01039948,
#         0.01100039, 0.01160002, 0.01019926, 0.01259947, 0.01059966,
#         0.00900011, 0.00999975, 0.0109992 , 0.01139994, 0.01139598,
#         0.00959845, 0.00979915, 0.01079564, 0.01119928, 0.0101995 ,
#         0.00939965, 0.01019988, 0.01060109, 0.01040072, 0.0116003 ,
#         0.01120071, 0.01060014, 0.01019998, 0.01080012, 0.01079998,
#         0.01080065, 0.01060019, 0.01180053, 0.01040082, 0.01159849,
#         0.00959992, 0.00999751, 0.01080027, 0.01119881, 0.01020002,
#         0.00939956, 0.01160092, 0.01059966, 0.01040039, 0.01019969,
#         0.01199975, 0.01059976, 0.0112009 , 0.00939999, 0.01120009,
#         0.01099977, 0.01059923, 0.00979948, 0.01079912, 0.01019926,
#         0.00960031, 0.01100006, 0.01080017, 0.0138    , 0.01039958,
#         0.01179986, 0.01140013, 0.01059957, 0.01120005, 0.01039987,
#         0.00980015, 0.01020007, 0.00980005, 0.00979996, 0.01100016,
#         0.01059957, 0.01079988, 0.01100016, 0.01059966, 0.01320095,
#         0.01239944, 0.01119957, 0.00920043, 0.01179991, 0.01139975,
#         0.01306927, 0.01306927, 0.01306927, 0.01306927, 0.01306927,
#         0.01306927, 0.01307833, 0.01307833, 0.01307833, 0.01307833,
#         0.01307833, 0.01307833, 0.01307833, 0.01307833, 0.01307833,
#         0.01307833, 0.01307833, 0.01307833, 0.01307833, 0.01307833,
#         0.01307833, 0.01307833, 0.01307833, 0.01307833, 0.01307833,
#         0.01307833, 0.01307833, 0.01307833, 0.01307833, 0.01307833,
#         0.01307833, 0.01307833, 0.01307833, 0.01307833, 0.01307833,
#         0.01307833, 0.01307833, 0.01307833, 0.01307833, 0.01307833,
#         0.01307833, 0.01307833, 0.01307833, 0.01307833, 0.01307833])}

# %%
cv_results = pd.DataFrame(cv.cv_results_.copy())

# %%
cv_results
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time param_C  \
# 0        0.010600      0.000800         0.004401        0.000490    0.01
# 1        0.013600      0.000800         0.004400        0.000490    1.02
# 2        0.011000      0.000895         0.003600        0.000800    2.03
# 3        0.012400      0.001625         0.004000        0.000632    3.04
# 4        0.013200      0.002315         0.003800        0.000749    4.05
# ..            ...           ...              ...             ...     ...
# 95       0.011400      0.001020         0.003400        0.000490   95.96
# 96       0.010800      0.001833         0.003400        0.000489   96.97
# 97       0.011000      0.000633         0.003400        0.000490   97.98
# 98       0.011001      0.001673         0.003800        0.000980   98.99
# 99       0.010201      0.001719         0.003200        0.000401   100.0
#
#                       params  split0_test_score  split1_test_score  \
# 0                {'C': 0.01}           0.656863           0.676329
# 1                {'C': 1.02}           0.637681           0.689320
# 2                {'C': 2.03}           0.640777           0.689320
# 3                {'C': 3.04}           0.640777           0.689320
# 4                {'C': 4.05}           0.643902           0.689320
# ..                       ...                ...                ...
# 95  {'C': 95.96000000000001}           0.643902           0.689320
# 96  {'C': 96.97000000000001}           0.643902           0.689320
# 97              {'C': 97.98}           0.643902           0.689320
# 98  {'C': 98.99000000000001}           0.643902           0.689320
# 99              {'C': 100.0}           0.643902           0.689320
#
#     split2_test_score  split3_test_score  ...  mean_test_score  \
# 0            0.666667           0.591549  ...         0.656829
# 1            0.660194           0.602871  ...         0.657339
# 2            0.660194           0.605769  ...         0.658538
# 3            0.657005           0.605769  ...         0.657900
# 4            0.657005           0.605769  ...         0.658525
# ..                ...                ...  ...              ...
# 95           0.657005           0.605769  ...         0.659312
# 96           0.657005           0.605769  ...         0.659312
# 97           0.657005           0.605769  ...         0.659312
# 98           0.657005           0.605769  ...         0.659312
# 99           0.657005           0.605769  ...         0.659312
#
#     std_test_score  rank_test_score  split0_train_score  split1_train_score  \
# 0         0.034721              100            0.658416            0.651048
# 1         0.034432               99            0.664132            0.651048
# 2         0.033170               79            0.663291            0.651907
# 3         0.033163               98            0.662453            0.651907
# 4         0.032862               80            0.662453            0.652709
# ..             ...              ...                 ...                 ...
# 95        0.033799                1            0.662453            0.650307
# 96        0.033799                1            0.662453            0.650307
# 97        0.033799                1            0.662453            0.650307
# 98        0.033799                1            0.662453            0.650307
# 99        0.033799                1            0.662453            0.650307
#
#     split2_train_score  split3_train_score  split4_train_score  \
# 0             0.657602            0.682560            0.656212
# 1             0.652709            0.687817            0.666667
# 2             0.651106            0.688691            0.666667
# 3             0.651907            0.686946            0.667485
# 4             0.651907            0.686150            0.667485
# ..                 ...                 ...                 ...
# 95            0.650307            0.685279            0.669127
# 96            0.650307            0.685279            0.669127
# 97            0.650307            0.685279            0.669127
# 98            0.650307            0.685279            0.669127
# 99            0.650307            0.685279            0.669127
#
#     mean_train_score  std_train_score
# 0           0.661168         0.010999
# 1           0.664475         0.013179
# 2           0.664332         0.013633
# 3           0.664139         0.012911
# 4           0.664141         0.012480
# ..               ...              ...
# 95          0.663494         0.013078
# 96          0.663494         0.013078
# 97          0.663494         0.013078
# 98          0.663494         0.013078
# 99          0.663494         0.013078
#
# [100 rows x 21 columns]

# %% [markdown]
# **Zadanie 7 (2 punkty)**
#
# 1. Wytrenuj kernel SVM z domyślnymi hiperparametrami:
#    - ustaw zbalansowane wagi klas
#    - zmierz czas treningu
#    - sprawdź F1-score na zbiorze testowym
#    - zmierz czas treningu
#    - pamiętaj o ustawieniu `random_state=0`
# 2. Wytrenuj kernel SVM z tuningiem hiperparametrów:
#    - sprawdź kilka siatek hiperparametrów (`param_grid` może być listą słowników!)
#    - dla kerneli RBF sprawdź 20 wartości `C` z zakresu od $10^{-2}$ do $10^2$, a dla `gamma` sprawdź wartość `"scale"` oraz 20 wartości z zakresu od $10^{-2}$ do $10^2$
#    - dla kernela wielomianowego sprawdź 100 wartości `C` z zakresu od $10^{-2}$ do $10^2$ oraz stopnie wielomianu z zakresu [2, 5]
#    - dla kernela sigmoidalnego sprawdź te same zakresy wartości, co dla RBF
# 3. Dokonaj analizy hiperparametrów po tuningu:
#    - sprawdź, dla jakich hiperparametrów osiągnięto najwyższy wynik walidacji skrośnej
#    - sprawdź, jaki był najlepszy wynik osiągnięty dla każdego z trzech kerneli
#    - wypisz hiperparametry dla każdego z tych przypadków
#    - który kernel wymagał najmocniejszej regularyzacji i jak sądzisz, czemu ten?
#    - wytrenuj SVM dla optymalnych hiperparametrów dla każdego z trzech kerneli i sprawdź F1-score na zbiorze testowym
#    - czy udało się dobrze oszacować wynik za pomocą walidacji skrośnej, tj. czy faktycznie kernel o najwyższym wyniku walidacyjnym miał najwyższy wynik testowy?

# %% [markdown]
# #### Default Kernel SVM

# %%
clf_kernel_svc = SVC(cache_size=512, class_weight="balanced", random_state=0)

start_time = time()
clf_kernel_svc.fit(X_train, y_train)
end_time = time()
fit_time = end_time - start_time

start_time = time()
y_pred = clf_kernel_svc.predict(X_test)
end_time = time()
pred_time = end_time - start_time

print(f"F1-score: {f1_score(y_test, y_pred)*100:.2f}%")
print(f"Training time: {fit_time:.2f} s")
print(f"Prediction time: {pred_time:.2f} s")
# Out:
# F1-score: 65.71%
# Training time: 0.08 s
# Prediction time: 0.04 s

# %% [markdown]
# #### Kernel SVM with hyperparameter tuning

# %%
data = X_train, y_train, X_test, y_test


def grid_search_kernel_SVM(data, clf, scoring="f1"):
    X_train, y_train, X_test, y_test = data

    param_grid = [
        {
            "kernel": ["rbf"],
            "C": np.linspace(1e-2, 1e2, 20),
            "gamma": list(["scale"] + list(np.linspace(1e-2, 1e2, 20))),
        },
        {
            "kernel": ["poly"],
            "C": np.linspace(1e-2, 1e2, 100),
            "degree": list(range(2, 6)),
        },
        {
            "kernel": ["sigmoid"],
            "C": np.linspace(1e-2, 1e2, 20),
            "gamma": list(["scale"] + list(np.linspace(1e-2, 1e2, 20))),
        },
    ]

    cv = GridSearchCV(
        estimator=clf,
        param_grid=param_grid,
        scoring=scoring,
        cv=5,
        n_jobs=-1,
        # return_train_score=True,
    )

    # Start of tuning in here
    # - run fit with all sets of parameters
    start_time = time()
    cv.fit(X_train, y_train)
    end_time = time()
    fit_time = end_time - start_time
    # End of tuning in here

    # Call predict on the estimator
    # with the best found parameters
    start_time = time()
    y_pred = cv.predict(X_test)
    end_time = time()
    pred_time = end_time - start_time

    print(f"Fit time: {fit_time:.2f} s")
    print(f"Prediction time: {pred_time:.2f} s")
    print(f"F1-score: {100 * f1_score(y_test, y_pred):.2f}%")

    return cv, y_pred

# %%
clf_kernel_svc = SVC(cache_size=512, class_weight="balanced", random_state=0)
clf_kernel_svc.fit(X_train, y_train);

# %%
cv, y_pred = grid_search_kernel_SVM(
    [X_train, y_train, X_test, y_test], clf_kernel_svc
)
# Out:
# Fit time: 246.49 s
# Prediction time: 0.03 s
# F1-score: 84.70%

# %% [markdown]
# - best hyperparameters set

# %%
# Best grid params of all
cv.best_params_
# Out:
# {'C': 78.94947368421053, 'gamma': 'scale', 'kernel': 'rbf'}

# %%
# Best mean score for cv splits
cv.best_score_
# Out:
# 0.8353073410927548

# %%
# Index of the best params set
# just to check something later
cv.best_index_
# Out:
# 315

# %% [markdown]
# - best score and params for every kernel

# %%
results = pd.DataFrame(cv.cv_results_.copy())
grouped_by_kernel = results.groupby("param_kernel")


def best_params_by_kernel(kernel_key, grouped_df=grouped_by_kernel) -> dict:
    return (
        grouped_df.get_group(kernel_key)
        .sort_values(by="mean_test_score", ascending=False)["params"]
        .head(1)
        .values[0]
    )


def best_scores_by_kernel(kernel_key, grouped_df=grouped_by_kernel) -> float:
    return (
        grouped_df.get_group(kernel_key)
        .sort_values(by="mean_test_score", ascending=False)
        .head(1)["mean_test_score"]
        .values[0]
    )


def print_summary(kernel_key):
    print(colored(f"{'-'*20}{kernel_key.upper()}{'-'*20}", "blue"))
    print(f"Best score: {best_scores_by_kernel(kernel_key)*100:.2f}%")
    print(f"Best score: {best_params_by_kernel(kernel_key)}")


for kernel_key in ["rbf", "poly", "sigmoid"]:
    print_summary(kernel_key)
# Out:
# --------------------RBF--------------------
# Best score: 83.53%
# Best score: {'C': 78.94947368421053, 'gamma': 'scale', 'kernel': 'rbf'}
# --------------------POLY--------------------
# Best score: 83.46%
# Best score: {'C': 86.87, 'degree': 5, 'kernel': 'poly'}
# --------------------SIGMOID--------------------
# Best score: 64.51%
# Best score: {'C': 5.272631578947368, 'gamma': 0.01, 'kernel': 'sigmoid'}

# %% [markdown]
# C to parametr regularyzacji, który jest odwrotnie proporcjonalny do siły regularyzacji => najmniejsze C to największa siła regularyzacji.
# Najmniejsze C (największą siłę reg.) widzimy dla kernela sigmoidalnego. Sigmoida jest funkcją ograniczoną. Szczerze mówiąc spodziewałam się, że wielomiany kernel będzie potrzebował największej siły regularyzacji, żeby "ściągnąć" w dół za wysokie wartości wielomianów (f. nieograniczone) i nie rozumiem, czemu jest na odwrót.

# %% [markdown]
# - SVM F1-scores benchmark

# %%
data = X_train, y_train, X_test, y_test


def fit_predict_svm(data, clf, kernel_key, scoring="f1"):
    X_train, y_train, X_test, y_test = data

    clf.fit(X_train, y_train)
    y_pred = clf.predict(X_test)

    print(
        f"Best cross-validation score: \
    {best_scores_by_kernel(kernel_key)*100:.2f}%"
    )
    print(f"F1-score: {100 * f1_score(y_test, y_pred):.2f}%")

    return y_pred

# %%
rbf_svc = SVC(
    C=78.94947368421053,
    gamma="scale",
    cache_size=512,
    class_weight="balanced",
    random_state=0,
)
fit_predict_svm(data, rbf_svc, "rbf");
# Out:
# Best cross-validation score:     83.53%
# F1-score: 84.70%

# %%
poly_svc = SVC(
    kernel="poly",
    C=86.87,
    degree=5,
    cache_size=512,
    class_weight="balanced",
    random_state=0,
)
fit_predict_svm(data, poly_svc, "poly");
# Out:
# Best cross-validation score:     83.46%
# F1-score: 82.71%

# %%
sigmoid_svc = SVC(
    kernel="sigmoid",
    C=5.272631578947368,
    gamma=0.01,
    cache_size=512,
    class_weight="balanced",
    random_state=0,
)
fit_predict_svm(data, sigmoid_svc, "sigmoid");
# Out:
# Best cross-validation score:     64.51%
# F1-score: 58.96%

# %% [markdown]
# Za pomocą walidacji skrośnej udał się dobrze oszacować wynik, tj. kernel o najwyższym wyniku walidacyjnym (rbf 83.53%) miał też najwyższy F1-score (rbf 84.70%). W przypadku poly różnica między tym kernelem a rbf była stosunkowo mała w walidacji skrośnej, ale już F1-score tutaj niższe. Dla sigmoidalnego kernela F1-score okazał się dużo niższy od wyniku średniego z walidacji skrośnej, jednak tamten wynik i tak był tak niski, że nie należało się tym kernelem w ogóle sugerować.

# %% [markdown]
# Nie uwzględniliśmy jednak jeszcze faktu, że nasi klienci mają różną wagę. Według badań koszt zyskania klienta jest około 15 razy wyższy od kosztu utrzymania klienta, który jest zagrożony przejściem dla konkurencji. W związku z tym FP i FN mają różną ważnośc. Dodatkowo sami klienci płacą mniej lub więcej, więc to też trzeba uwzględnić. Na szczęście my mamy już to zrobione, bo mamy macierze `fp_cost` oraz `fn_cost` oznaczające koszt pomylenia się na oba sposoby w przypadku każdego klienta.
#
# Powinniśmy zatem używać **ważonej metryki (weighted metric)**, która dla każdego przykładu stosuje odpowiednią wagę, i to w zależności od tego, w jaki sposób się pomyliliśmy. Tego typu metryki typowo działają jak funkcje kosztu - im mniejsza wartość, tym lepiej, bo często dosłownie reprezentują koszt, jaki firma musi ponieść przy stosowaniu danego algorytmu. Wykorzystanie takiej metryki to **cost-sensitive classification**.
#
# **Zadanie 8 (0.5 punktu)**
#
# 1. Uzupełnij kod funkcji `churn_cost()`, która oblicza koszt dokonania danej klasyfikacji.
# 2. Stwórz funkcję w postaci akceptowanej przez `GridSearchCV` za pomocą `make_scorer`. Zwróć uwagę, żeby podać do niej prawidłowe argumenty.

# %%
from typing import Union

from sklearn.metrics import make_scorer


def churn_cost(
    y_true: Union[np.ndarray, pd.Series],
    y_pred: Union[np.ndarray, pd.Series],
    fp_cost: Union[np.ndarray, pd.Series],
    fn_cost: Union[np.ndarray, pd.Series],
) -> float:
    # make sure all data is Numpy arrays
    y_true = np.array(y_true)
    y_pred = np.array(y_pred)
    fp_cost = np.array(fp_cost)
    fn_cost = np.array(fn_cost)

    # check which rows are for FP and FN
    fp_rows = np.intersect1d(np.where(y_true == 0), np.where(y_pred == 1))
    fn_rows = np.intersect1d(np.where(y_true == 1), np.where(y_pred == 0))

    # get costs for FP and FN
    fps_sum = np.sum(fp_cost[fp_rows])
    fns_sum = np.sum(fn_cost[fn_rows])

    # return sum of costs
    return fps_sum + fns_sum


churn_cost_score = make_scorer(
    churn_cost,
    greater_is_better=False,
    fp_cost=fp_cost_test,
    fn_cost=fn_cost_test,
)

# %% [markdown]
# **Zadanie 9 (1 punkt)**
#
# 1. Wytrenuj klasyfikatory stały `DummyClassifier`:
#    - taki, który zawsze przewiduje klasę negatywną (brak zmiany)
#    - taki, który zawsze przewiduje klasę pozytywną (churn)
# 2. Sprawdź metrykę F1-score oraz nasz nowo zdefiniowany churn cost dla takich rozwiązań na zbiorze testowym. Wykorzystaj `fp_cost_test` oraz `fn_cost_test`.
# 3. Lepiej jest stosować reklamy dla wszystkich, czy po prostu zgodzić się na churn i nic z tym nie robić? Uwzględniając liczbę próbek w zbiorze testowym, czy twoim zdaniem wysoki koszt? Załóż, że walutą są dolary - irański rial zawsze był tak słabą walutą, że i tak używano walut zagranicznych, co widać też w tym zbiorze. Wartość każdego klienta jest typowo wysoka, bo to obliczona tzw. lifetime value - przewidywana potencjalna wartość klienta w przyszłości.

# %%
from sklearn.dummy import DummyClassifier


neg_dummy_clf = DummyClassifier(
    strategy="constant", random_state=0, constant=0
)
pos_dummy_clf = DummyClassifier(
    strategy="constant", random_state=0, constant=1
)

neg_dummy_clf.fit(X_train, y_train)
pos_dummy_clf.fit(X_train, y_train)

neg_dummies_pred = neg_dummy_clf.predict(X_test)
pos_dummies_pred = pos_dummy_clf.predict(X_test)

# %%
f1_score_neg = f1_score(y_test, neg_dummies_pred)
f1_score_pos = f1_score(y_test, pos_dummies_pred)

print(
    f"Negative (assuming everybody stays) \
dummy f1 score: {f1_score_neg*100:.2f}%"
)
print(
    f"Positive (assuming everybody leaves) \
dummy f1 score: {f1_score_pos*100:.2f}%"
)
print()

churn_score_neg = churn_cost_score(neg_dummy_clf, X_test, y_test)
churn_score_pos = churn_cost_score(pos_dummy_clf, X_test, y_test)

print(
    f"Negative (assuming everybody stays) dummy churn cost score: \
{churn_score_neg:.2f}"
)
print(
    f"Positive (assuming everybody leaves) dummy churn cost score: \
{churn_score_pos:.2f}"
)
print()

# greater_is_better=False sign-flips the scorer outcome
print(
    f"Negative (assuming everybody stays) dummy \
churn cost score absolute value: {-1*churn_score_neg:.2f}$"
)
print(
    f"Positive (assuming everybody leaves) dummy \
churn cost score absolute value: {-1*churn_score_pos:.2f}$"
)
print()

outcome_per_customer = lambda outcome: outcome / X_test.shape[0]
print(
    f"Negative (assuming everybody stays) dummy avg \
{outcome_per_customer(-1*churn_score_neg):.2f}$ per customer"
)
print(
    f"Positive (assuming everybody leaves) dummy avg \
{outcome_per_customer(-1*churn_score_pos):.2f}$ per customer"
)
# Out:
# Negative (assuming everybody stays) dummy f1 score: 0.00%
# Positive (assuming everybody leaves) dummy f1 score: 27.19%
#
# Negative (assuming everybody stays) dummy churn cost score: -15871.64
# Positive (assuming everybody leaves) dummy churn cost score: -69593.20
#
# Negative (assuming everybody stays) dummy churn cost score absolute value: 15871.64$
# Positive (assuming everybody leaves) dummy churn cost score absolute value: 69593.20$
#
# Negative (assuming everybody stays) dummy avg 20.14$ per customer
# Positive (assuming everybody leaves) dummy avg 88.32$ per customer

# %%
print(f"Test dataset FN:\n{fn_cost_test.describe()}\n")
print(f"Test dataset FP:\n{fp_cost_test.describe()}\n")
print(f"Test dataset FN sum: {np.sum(fn_cost_test):.2f}")
print(f"Test dataset FP sum: {np.sum(fp_cost_test):.2f}\n")

print(
    f"Dummy positive churn score / money on making everybody stay: \
{-1*churn_score_pos / np.sum(fp_cost_test):.2f}"
)
print(
    f"Dummy negative churn score / all clients loss: \
{-1*churn_score_neg / np.sum(fn_cost_test):.2f}\n"
)

print(
    f"Dummy positive churn score / dummy negative \
churn score: {churn_score_pos / churn_score_neg:.4f}"
)
print(
    f"FN sum / FP sum: \
{np.sum(fn_cost_test) / np.sum(fp_cost_test):.4f}"
)
# Out:
# Test dataset FN:
# count     788.000000
# mean      428.737877
# std       480.416437
# min         0.000000
# 25%       100.494000
# 50%       194.996250
# 75%       721.183500
# max      1948.752000
# Name: FN, dtype: float64
#
# Test dataset FP:
# count    788.000000
# mean      98.877120
# std       52.393334
# min       60.000000
# 25%       61.166000
# 50%       71.666250
# 75%      130.131500
# max      266.528000
# Name: FP, dtype: float64
#
# Test dataset FN sum: 337845.45
# Test dataset FP sum: 77915.17
#
# Dummy positive churn score / money on making everybody stay: 0.89
# Dummy negative churn score / all clients loss: 0.05
#
# Dummy positive churn score / dummy negative churn score: 4.3848
# FN sum / FP sum: 4.3361

# %% [markdown]
# // skomentuj tutaj
#
# Z powyższych bezwzględnych wartości wynika, że ponad 4-krotnie większy koszt ponosi się traktując każdego klienta reklamami/promocjami niż godząc się na churn każdego klienta bez walki. Co lepiej stosować zależy już chyba od szerszego kontekstu finansowo-marketingowego firmy.
# Funfakty nt. walki o klientów zbioru testowego:
# - stosunek (dummy positive churn score) / (koszta błędnej walki o wszystkich) = 89%. => Walka o klientów, którzy faktycznie odeszli, stanowiła 11% kosztów potencjalnnej walki o wszystkich klientów zbioru testowego (zał., że odejdzie każdy i o każdego walczymy).
# - stosunek (dummy negative churn score) / (straty z tytułu pozwolenia wszystkim odejśc) = 0.05%. => Straty z powodu rzeczywistej utraty klientów zbioru testowego stanowiły 5% strat z tytułu pozwolenia wszystkim klientom zbioru testowego odejść.
#
# Czy ww. kwoty w przeliczeniu na klienta to dużo, zależy też od tego czy dane podawane są w dolarach po uwzględnieniu siły nabywczej waluty irańskiej, czy jako bezwzględny ekwiwalent po kursie dolar irański -> dolar amerykański. 20$ per klient jako lifetime value w USA to bardzo niska kwota.

# %% [markdown]
# **Zadanie 10 (1 punkt)**
#
# 1. Wytrenuj liniowy SVM, wykorzystaj znalezioną wcześniej optymalną wartość `C`. Innych parametrów użyj tak, jak wcześniej. Jaki jest koszt przy wdrożeniu takiego rozwiązania? Ile zyskujemy względem najlepszego rozwiązania z poprzedniego zadania?
# 2. Wytrenuj kernel SVM, wykorzystaj znalezione wcześniej optymalne wartości hiperparametrów. Innych parametrów użyj tak, jak wcześniej. O ile lepszy jest koszt? O ile lepszy jest od modelu liniowego, jakim jest liniowy SVM?
# 3. Czy twoim zdaniem warto wdrażać rozwiązania oparte o ML do takich zadań?

# %% [markdown]
# // skomentuj tutaj

# %% [markdown]
# ## Zadanie dodatkowe (3 punkty)
#
# W przypadku, kiedy zastosowanie kernel SVM wprost byłoby zbyt kosztowne, można zamiast tego przybliżyć cechy kernelowe. Realizują to algorytmy grupy kernel approximation.
#
# Metoda Nyströma to algorytm uniwersalny, który potrafi przybliżyć dowolny kernel. Wykorzystuje do tego truncated SVD, czyli przybliża wprost kernel matrix za pomocą macierzy niższej rangi. Ceną tej prostoty i uniwersalności jest nie najlepsza prędkość działania w porównaniu do bardziej specjalistycznych algorytmów. Proste wyprowadzenie tej metody można znaleźć [tutaj](https://stats.stackexchange.com/questions/261149/nystroem-method-for-kernel-approximation).
#
# `RBFSampler` w Scikit-learn implementuje metodę Random Kitchen Sinks. Ten algorytm za pomocą próbkowania Monte Carlo przybliża coraz lepiej macierz kernela RBF. W bibliotece Scikit-learn-extra zaimplementowane jest rozwinięcie tego algorytmu o nazwie [Fastfood](https://scikit-learn-extra.readthedocs.io/en/stable/generated/sklearn_extra.kernel_approximation.Fastfood.html), który stosuje nieco bardziej zaawansowany algorytm przybliżający, który powinien być jeszcze szybszy i oszczędniejszy pamięciowo.
#
# Hiperparametry tych metod są podobne do zwykłego kernel SVM, ale dodatkowo mamy wymiarowość naszego przybliżenia, czyli `n_components`. Im większe, tym dokładniej przybliżamy, ale też tym więcej mamy cech. Wejściem do metody Nyströma jest macierz cech X, a wyjściem macierz cech kernelowych X mająca rozmiar `n_samples * n_components`. Na takich cechach trenuje się już zwykły liniowy SVM.
#
# 1. Zaimplementuj `Pipeline` składający się z przybliżenia kernela oraz liniowego SVM: dla metody Nyströma, oraz dla obu algorytmów dla kernela RBF.
# 2. Wytrenuj algorytmy z domyślnymi hiperparametrami. Porównaj jakość predykcji oraz szybkość z liniowym SVM i z kernel SVM. Czy warto dokonać takiej aproksymacji?
# 3. Dokonaj optymalizacji hiperparametrów `C`, `gamma` oraz `n_components`. Czy udało się poprawić wynik względem zwykłego kernel SVM w rozsądnym czasie?

# %% [markdown]
# // skomentuj tutaj
